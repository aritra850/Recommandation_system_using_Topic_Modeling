# %%
from banglakit import lemmatizer
from banglakit.lemmatizer import BengaliLemmatizer
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize

# %%
lm = BengaliLemmatizer()

# %%
lm.lemmatize("ভারতের",pos=lemmatizer.POS_PROPN)
# Out:
# 'ভারতের'

# %%
 lam = WordNetLemmatizer()

# %%
import nltk
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\omw-1.4.zip.
# True

# %%
lam.lemmatize("ভারতের")
# Out:
# 'ভারতের'

# %%
tokens = word_tokenize("স্রেফ দু’টি টুইটেই সোশ্যাল মিডিয়ায় তোলপাড় ফেলে দিয়েছেন সিদ্ধার্থ সূর্যনারায়ণ। এমন দু’টি কথা তিনি বলেছেন, যা একইসঙ্গে সমাজ এবং সিনেমাকে একসুতোয় বেঁধেছে।\nমহিলাদের পিছু নেওয়া, তাঁদের উত্ত্যক্ত করা ঘিরে আলোচনা চলছে সর্বত্র। চেন্নাইয়ের রাস্তায় দিনেদুপুরে এক মহিলাকে খুন করা হয়েছে সম্প্রতি। নারীসুরক্ষা নিয়ে চলছে আলোচনা, মত বিনিময়। ঠিক এইরকম একটি পরিস্থিতিতে সিদ্ধার্থের জোড়া টুইট আত্মসমালোচনার সামিল। কীভাবে এই সামাজিক অভিশাপের নেপথ্যে সিনেমারও দায় থেকে যায়, তা স্পষ্টভাষায় তুলে ধরেছেন সিদ্ধার্থ। কোনও রাখঢাক না-করেই তিনি বলেছেন, সিনেমায় এমনটি একটি স্বপ্ন ফেরি করার চেষ্টা চলে, যা সম্পূর্ণ ভুল।\nকীভাবে?\n\nসিদ্ধার্থ তুলে এনেছেন ভারতীয় ছবিতে বহু-ব্যবহৃত এবং জনপ্রিয় একটি সিকোয়েন্সের প্রসঙ্গ। যেখানে নায়িকার পিছু নিতে দেখা যায় নায়ককে। পরিণতি? দেখানো হয়, প্রাথমিকভাবে বিরক্ত হলেও, সময়ক্রমে নায়িকা অনিবার্যভাবে নায়কের প্রেমে হাবুডুবু খেতে শুরু করেছেন। এই ধরনের দৃশ্য এত বেশি এবং এতভাবে ব্যবহার করা হয়েছে, যা কোথাও গিয়ে পিছু নেওয়া ব্যাপারটিতে একটি সিলমোহর দিয়েছে বলে মনে করেন সিদ্ধার্থ। তাঁর সাফ কথা, সমাজের প্রতি সকলের একটি ‘‘সামগ্রিক দায়বদ্ধতা’’ রয়েছে। প্রথম টুইটে সিদ্ধার্থ লিখেছেন, ‘‘দীর্ঘদিন ধরে আমরা আমাদের ছবিতে একটি ভয়ঙ্কর স্বপ্ন ফেরি করে চলেছি। সেটা হল, যে কোনও মহিলাকে পছন্দ হলেই তাঁর পিছু নিতে শুরু করেন একজন পুরুষ। এই পরিস্থিতির অবশ্যই পরিবর্তন করতে হবে।’’\nএখানেই থামেননি দক্ষিণের এই অভিনেতা। দ্বিতীয় টুইটটি আরও বিস্ফোরক। লিখেছেন, ‘‘আমাদের ছবিতে কোনও মহিলা যখন কোনও পুরুষের পিছু নেন, তখন তিনি খলনায়িকা। কিন্তু একজন পুরুষ কোনও মহিলার পিছু নিলে তিনি নায়ক। এটি একটি জটিল আলোচনা। কিন্তু এই আলোচনাটি হওয়া প্রয়োজন।’’\nকী মনে হয়? কোনও প্রশংসাই সম্ভবত যথেষ্ট নয়।\n")

# %%
ti = [lam.lemmatize(word) for word in tokens]
ti
# Out:
# ['স্রেফ',
#  'দু',
#  '’',
#  'টি',
#  'টুইটেই',
#  'সোশ্যাল',
#  'মিডিয়ায়',
#  'তোলপাড়',
#  'ফেলে',
#  'দিয়েছেন',
#  'সিদ্ধার্থ',
#  'সূর্যনারায়ণ।',
#  'এমন',
#  'দু',
#  '’',
#  'টি',
#  'কথা',
#  'তিনি',
#  'বলেছেন',
#  ',',
#  'যা',
#  'একইসঙ্গে',
#  'সমাজ',
#  'এবং',
#  'সিনেমাকে',
#  'একসুতোয়',
#  'বেঁধেছে।',
#  'মহিলাদের',
#  'পিছু',
#  'নেওয়া',
#  ',',
#  'তাঁদের',
#  'উত্ত্যক্ত',
#  'করা',
#  'ঘিরে',
#  'আলোচনা',
#  'চলছে',
#  'সর্বত্র।',
#  'চেন্নাইয়ের',
#  'রাস্তায়',
#  'দিনেদুপুরে',
#  'এক',
#  'মহিলাকে',
#  'খুন',
#  'করা',
#  'হয়েছে',
#  'সম্প্রতি।',
#  'নারীসুরক্ষা',
#  'নিয়ে',
#  'চলছে',
#  'আলোচনা',
#  ',',
#  'মত',
#  'বিনিময়।',
#  'ঠিক',
#  'এইরকম',
#  'একটি',
#  'পরিস্থিতিতে',
#  'সিদ্ধার্থের',
#  'জোড়া',
#  'টুইট',
#  'আত্মসমালোচনার',
#  'সামিল।',
#  'কীভাবে',
#  'এই',
#  'সামাজিক',
#  'অভিশাপের',
#  'নেপথ্যে',
#  'সিনেমারও',
#  'দায়',
#  'থেকে',
#  'যায়',
#  ',',
#  'তা',
#  'স্পষ্টভাষায়',
#  'তুলে',
#  'ধরেছেন',
#  'সিদ্ধার্থ।',
#  'কোনও',
#  'রাখঢাক',
#  'না-করেই',
#  'তিনি',
#  'বলেছেন',
#  ',',
#  'সিনেমায়',
#  'এমনটি',
#  'একটি',
#  'স্বপ্ন',
#  'ফেরি',
#  'করার',
#  'চেষ্টা',
#  'চলে',
#  ',',
#  'যা',
#  'সম্পূর্ণ',
#  'ভুল।',
#  'কীভাবে',
#  '?',
#  'সিদ্ধার্থ',
#  'তুলে',
#  'এনেছেন',
#  'ভারতীয়',
#  'ছবিতে',
#  'বহু-ব্যবহৃত',
#  'এবং',
#  'জনপ্রিয়',
#  'একটি',
#  'সিকোয়েন্সের',
#  'প্রসঙ্গ।',
#  'যেখানে',
#  'নায়িকার',
#  'পিছু',
#  'নিতে',
#  'দেখা',
#  'যায়',
#  'নায়ককে।',
#  'পরিণতি',
#  '?',
#  'দেখানো',
#  'হয়',
#  ',',
#  'প্রাথমিকভাবে',
#  'বিরক্ত',
#  'হলেও',
#  ',',
#  'সময়ক্রমে',
#  'নায়িকা',
#  'অনিবার্যভাবে',
#  'নায়কের',
#  'প্রেমে',
#  'হাবুডুবু',
#  'খেতে',
#  'শুরু',
#  'করেছেন।',
#  'এই',
#  'ধরনের',
#  'দৃশ্য',
#  'এত',
#  'বেশি',
#  'এবং',
#  'এতভাবে',
#  'ব্যবহার',
#  'করা',
#  'হয়েছে',
#  ',',
#  'যা',
#  'কোথাও',
#  'গিয়ে',
#  'পিছু',
#  'নেওয়া',
#  'ব্যাপারটিতে',
#  'একটি',
#  'সিলমোহর',
#  'দিয়েছে',
#  'বলে',
#  'মনে',
#  'করেন',
#  'সিদ্ধার্থ।',
#  'তাঁর',
#  'সাফ',
#  'কথা',
#  ',',
#  'সমাজের',
#  'প্রতি',
#  'সকলের',
#  'একটি',
#  '‘',
#  '‘',
#  'সামগ্রিক',
#  'দায়বদ্ধতা',
#  '’',
#  '’',
#  'রয়েছে।',
#  'প্রথম',
#  'টুইটে',
#  'সিদ্ধার্থ',
#  'লিখেছেন',
#  ',',
#  '‘',
#  '‘',
#  'দীর্ঘদিন',
#  'ধরে',
#  'আমরা',
#  'আমাদের',
#  'ছবিতে',
#  'একটি',
#  'ভয়ঙ্কর',
#  'স্বপ্ন',
#  'ফেরি',
#  'করে',
#  'চলেছি।',
#  'সেটা',
#  'হল',
#  ',',
#  'যে',
#  'কোনও',
#  'মহিলাকে',
#  'পছন্দ',
#  'হলেই',
#  'তাঁর',
#  'পিছু',
#  'নিতে',
#  'শুরু',
#  'করেন',
#  'একজন',
#  'পুরুষ।',
#  'এই',
#  'পরিস্থিতির',
#  'অবশ্যই',
#  'পরিবর্তন',
#  'করতে',
#  'হবে।',
#  '’',
#  '’',
#  'এখানেই',
#  'থামেননি',
#  'দক্ষিণের',
#  'এই',
#  'অভিনেতা।',
#  'দ্বিতীয়',
#  'টুইটটি',
#  'আরও',
#  'বিস্ফোরক।',
#  'লিখেছেন',
#  ',',
#  '‘',
#  '‘',
#  'আমাদের',
#  'ছবিতে',
#  'কোনও',
#  'মহিলা',
#  'যখন',
#  'কোনও',
#  'পুরুষের',
#  'পিছু',
#  'নেন',
#  ',',
#  'তখন',
#  'তিনি',
#  'খলনায়িকা।',
#  'কিন্তু',
#  'একজন',
#  'পুরুষ',
#  'কোনও',
#  'মহিলার',
#  'পিছু',
#  'নিলে',
#  'তিনি',
#  'নায়ক।',
#  'এটি',
#  'একটি',
#  'জটিল',
#  'আলোচনা।',
#  'কিন্তু',
#  'এই',
#  'আলোচনাটি',
#  'হওয়া',
#  'প্রয়োজন।',
#  '’',
#  '’',
#  'কী',
#  'মনে',
#  'হয়',
#  '?',
#  'কোনও',
#  'প্রশংসাই',
#  'সম্ভবত',
#  'যথেষ্ট',
#  'নয়।']

# %%
tib = [lm.lemmatize(word,pos = 'verb') for word in tokens]
tib
# Out:
# ['স্রেফ',
#  'দু',
#  '’',
#  'টি',
#  'টুইটেই',
#  'সোশ্যাল',
#  'মিডিয়ায়',
#  'তোলপাড়',
#  'ফেলে',
#  'দিয়েছেন',
#  'সিদ্ধার্থ',
#  'সূর্যনারায়ণ।',
#  'এমন',
#  'দু',
#  '’',
#  'টি',
#  'কথা',
#  '-PRON-',
#  'বল',
#  ',',
#  '-PRON-',
#  'একইসঙ্গে',
#  'সমাজ',
#  'এবং',
#  'সিনেমাকে',
#  'একসুতোয়',
#  'বেঁধেছে।',
#  'মহিলাদের',
#  'পিছু',
#  'নেওয়া',
#  ',',
#  'তাঁদের',
#  'উত্ত্যক্ত',
#  'কর',
#  'ঘিরে',
#  'আলোচনা',
#  'চলছে',
#  'সর্বত্র।',
#  'চেন্নাইয়ের',
#  'রাস্তায়',
#  'দিনেদুপুরে',
#  'এক',
#  'মহিলাকে',
#  'খুন',
#  'কর',
#  'হয়েছে',
#  'সম্প্রতি।',
#  'নারীসুরক্ষা',
#  'নিয়ে',
#  'চলছে',
#  'আলোচনা',
#  ',',
#  'মত',
#  'বিনিময়।',
#  'ঠিক',
#  'এইরকম',
#  'একটি',
#  'পরিস্থিতিতে',
#  'সিদ্ধার্থের',
#  'জোড়া',
#  'টুইট',
#  'আত্মসমালোচনার',
#  'সামিল।',
#  'কীভাবে',
#  'এই',
#  'সামাজিক',
#  'অভিশাপের',
#  'নেপথ্যে',
#  'সিনেমারও',
#  'দায়',
#  'থেকে',
#  'যাওয়া',
#  ',',
#  'তা',
#  'স্পষ্টভাষায়',
#  'তুল',
#  'ধর',
#  'সিদ্ধার্থ।',
#  'কোনও',
#  'রাখঢাক',
#  'না-করেই',
#  '-PRON-',
#  'বল',
#  ',',
#  'সিনেমায়',
#  'এমনটি',
#  'একটি',
#  'স্বপ্ন',
#  'ফেরি',
#  'করার',
#  'চেষ্টা',
#  'চলে',
#  ',',
#  '-PRON-',
#  'সম্পূর্ণ',
#  'ভুল।',
#  'কীভাবে',
#  '?',
#  'সিদ্ধার্থ',
#  'তুল',
#  'এনেছেন',
#  'ভারতীয়',
#  'ছবিতে',
#  'বহু-ব্যবহৃত',
#  'এবং',
#  'জনপ্রিয়',
#  'একটি',
#  'সিকোয়েন্সের',
#  'প্রসঙ্গ।',
#  'যেখানে',
#  'নায়িকার',
#  'পিছু',
#  'নিতে',
#  'দেখ',
#  'যাওয়া',
#  'নায়ককে।',
#  'পরিণতি',
#  '?',
#  'দেখানো',
#  'হয়',
#  ',',
#  'প্রাথমিকভাবে',
#  'বিরক্ত',
#  'হলেও',
#  ',',
#  'সময়ক্রমে',
#  'নায়িকা',
#  'অনিবার্যভাবে',
#  'নায়কের',
#  'প্রেমে',
#  'হাবুডুবু',
#  'খাওয়া',
#  'শুরু',
#  'করেছেন।',
#  'এই',
#  'ধরনের',
#  'দৃশ্য',
#  'এত',
#  'বেশি',
#  'এবং',
#  'এতভাবে',
#  'ব্যবহার',
#  'কর',
#  'হয়েছে',
#  ',',
#  '-PRON-',
#  'কোথাও',
#  'গিয়ে',
#  'পিছু',
#  'নেওয়া',
#  'ব্যাপারটিতে',
#  'একটি',
#  'সিলমোহর',
#  'দিয়েছে',
#  'বল',
#  'মনে',
#  'কর',
#  'সিদ্ধার্থ।',
#  'তাঁর',
#  'সাফ',
#  'কথা',
#  ',',
#  'সমাজের',
#  'প্রতি',
#  'সকলের',
#  'একটি',
#  '‘',
#  '‘',
#  'সামগ্রিক',
#  'দায়বদ্ধতা',
#  '’',
#  '’',
#  'রয়েছে।',
#  'প্রথম',
#  'টুইটে',
#  'সিদ্ধার্থ',
#  'লিখ',
#  ',',
#  '‘',
#  '‘',
#  'দীর্ঘদিন',
#  'ধর',
#  '-PRON-',
#  '-PRON-',
#  'ছবিতে',
#  'একটি',
#  'ভয়ঙ্কর',
#  'স্বপ্ন',
#  'ফেরি',
#  'কর',
#  'চলেছি।',
#  'সেটা',
#  'হল',
#  ',',
#  '-PRON-',
#  'কোনও',
#  'মহিলাকে',
#  'পছন্দ',
#  'হলেই',
#  'তাঁর',
#  'পিছু',
#  'নিতে',
#  'শুরু',
#  'কর',
#  'একজন',
#  'পুরুষ।',
#  'এই',
#  'পরিস্থিতির',
#  'অবশ্যই',
#  'পরিবর্তন',
#  'কর',
#  'হবে।',
#  '’',
#  '’',
#  'এখানেই',
#  'থামেননি',
#  'দক্ষিণের',
#  'এই',
#  'অভিনেতা।',
#  'দ্বিতীয়',
#  'টুইটটি',
#  'আরও',
#  'বিস্ফোরক।',
#  'লিখ',
#  ',',
#  '‘',
#  '‘',
#  '-PRON-',
#  'ছবিতে',
#  'কোনও',
#  'মহিলা',
#  'যখন',
#  'কোনও',
#  'পুরুষের',
#  'পিছু',
#  'নেন',
#  ',',
#  'তখন',
#  '-PRON-',
#  'খলনায়িকা।',
#  'কিন্তু',
#  'একজন',
#  'পুরুষ',
#  'কোনও',
#  'মহিলার',
#  'পিছু',
#  'নিলে',
#  '-PRON-',
#  'নায়ক।',
#  'এটি',
#  'একটি',
#  'জটিল',
#  'আলোচনা।',
#  'কিন্তু',
#  'এই',
#  'আলোচনাটি',
#  'হওয়া',
#  'প্রয়োজন।',
#  '’',
#  '’',
#  'কী',
#  'মনে',
#  'হয়',
#  '?',
#  'কোনও',
#  'প্রশংসাই',
#  'সম্ভবত',
#  'যথেষ্ট',
#  'নয়।']
